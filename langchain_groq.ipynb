# %% [markdown]
# <a href="https://colab.research.google.com/github/durgaprasadkantipudi/AgenticAI-Generative-AI-ML-DA-FSDS_CODES_EXPERTISE/blob/main/langchain_groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

# %%
#Chatgroq is  a method to access llm model using a key

# %%
#chatgroq(apikey,model,temper)
